# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = make_circles(n_samples=750, factor=0.3, noise = 0.1)

# %%
X
# Out:
# array([[ 0.56254098,  0.77930396],
#        [-0.02947029,  0.4091154 ],
#        [ 0.25429737,  0.80641073],
#        ...,
#        [ 0.23149185,  0.96768762],
#        [-0.06228817,  0.16472859],
#        [-0.92394376, -0.53078192]], shape=(750, 2))

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.10)

# %%
predictions = dbscan.fit_predict(X)

# %%
dbscan.labels_
# Out:
# array([ 0,  1, -1,  2,  1,  1,  1,  1, -1,  1,  3,  4,  5,  6,  1,  5,  1,
#         1,  1,  7,  3,  1,  1,  8,  6,  1,  6,  1,  1,  1,  2,  1,  1,  8,
#         8,  1,  5,  1,  0,  9,  1,  1,  1,  1,  1,  8,  1,  5,  8,  0,  5,
#        -1,  1,  1,  0,  5,  2,  1,  6,  5,  4,  1,  1,  6,  6,  8,  1,  5,
#         1,  1,  2,  5,  1,  2,  5,  9,  2,  5, -1,  1, -1,  6,  1, 10,  1,
#         5,  1,  8,  1,  3,  5,  6,  1,  1,  8,  8,  1, -1,  1,  1,  8,  1,
#         6,  1,  1,  1,  1,  1,  1,  1,  9,  6,  5,  1,  1, -1,  1,  1,  1,
#         6,  1,  1,  1,  1,  1,  1,  8,  1,  1,  1,  8,  1,  1,  4,  1,  6,
#         8,  1, 11,  1,  5, -1,  1,  1,  1,  1,  1,  1,  1,  5,  5,  2, 11,
#         1,  1,  1,  2,  1,  1,  9,  1,  1,  1, -1,  4,  3,  1,  1,  1,  8,
#         4, -1,  1,  9,  1, 10,  9,  8,  5,  1,  1,  6,  1,  1,  8,  1,  8,
#         6,  5,  6,  0,  1,  1,  1,  1,  1,  8,  8,  2,  1,  1,  1,  1,  1,
#         1, 12,  8,  1,  1,  5,  8,  1,  2, 11,  5,  8, -1,  6,  1, 10, -1,
#         1,  6,  1,  3,  1,  1,  5,  1,  1,  1,  1,  1,  1,  1,  1,  1,  5,
#         1,  5,  2,  7,  1,  1,  1,  1,  1,  1,  1,  3,  1,  1,  1, 10,  4,
#         2,  8,  6,  8,  1,  8,  2,  1,  1,  1,  1,  5,  4,  6,  6, -1,  1,
#         5,  1,  6,  1,  1,  4,  6, -1,  4,  3,  1,  1,  1,  5,  1,  5,  1,
#         3,  1,  1,  1, -1,  1,  3,  8,  1,  1,  9,  5,  6,  5,  5,  6,  8,
#         1,  1,  1,  1,  1,  5,  9,  1,  1,  8,  1,  1,  5,  1,  1,  5,  1,
#         1,  2,  1,  1, 10,  4,  1, -1,  9,  1,  8,  1,  1,  5,  6, 10,  1,
#         1,  5,  1,  8,  1,  1,  1,  1,  1,  5,  4,  8,  1,  1,  1,  8,  6,
#        -1,  8,  4, -1,  9,  4,  5,  0,  6,  4,  4,  1,  1,  2,  8,  3,  4,
#         3,  1,  1,  1,  6,  1, -1,  1, -1,  8,  5,  1,  5,  5,  1,  1,  6,
#         2,  8,  8,  1,  6,  1,  6,  1,  1, -1,  5,  1,  3,  1,  1, -1,  1,
#         1,  8,  1,  1,  1,  5,  1,  6,  3,  1,  1,  1, -1,  1,  1, 10,  1,
#         1,  1,  8,  7,  7, 10, -1,  2,  1,  1,  0, -1,  5,  1,  1,  5,  1,
#         1,  8,  6,  3,  5,  1,  1,  2,  6,  1, -1,  2,  8,  4,  5,  8,  8,
#         1,  4,  1,  2,  5,  1,  1,  6,  1,  1,  4,  2,  5,  1,  5,  1,  4,
#         1,  1,  6, -1,  1,  4,  1,  1,  1,  1,  1,  1,  1,  1,  6,  8,  1,
#         8,  7,  1,  1,  1,  1,  6,  1,  1, -1,  6,  1,  8,  1, -1,  8,  1,
#         1,  6,  1,  1,  1,  5,  0,  1,  1,  6,  5,  1,  1,  1,  5,  1,  2,
#         0,  8,  8,  1,  1,  1,  1,  8, 10,  2, -1,  1,  1,  1,  1,  1,  1,
#         1,  3,  1,  5,  4,  1,  1,  3, 11,  1,  1,  5,  6,  7,  1,  5,  2,
#         7,  1, 10, 10,  1, -1,  5,  1,  1,  1,  1,  1,  0, -1,  6,  8,  0,
#         8,  1,  1,  1,  0,  1, -1,  9,  1,  1,  1,  1,  1,  1,  5,  1,  1,
#         2,  5,  2,  8,  0, 10,  1,  6,  1,  1, 12,  1,  6,  1, -1,  1,  5,
#         1,  5,  2,  1,  8, -1,  5,  1,  1,  3,  4,  8,  6,  8,  1,  8,  4,
#         5, -1,  5,  9,  1,  5,  1,  9,  1,  5,  5,  7,  0,  1,  5,  5,  1,
#         3,  1,  1,  1,  3,  1,  1, 12,  1,  1,  2,  1,  2,  9,  8,  2,  1,
#         1,  6,  5,  2,  5,  6,  3,  1,  5,  1,  5,  8,  2,  9,  1,  1,  1,
#        10,  0,  1,  1,  1,  1,  5,  1,  1, -1,  5,  3,  1,  1,  5,  1,  1,
#         1,  5, 10,  1,  1,  1,  1,  5,  1,  1,  6,  1,  1,  1,  8,  2,  6,
#         8,  1,  5,  1,  1,  1, -1,  1,  1,  1,  2,  2,  8, -1,  1,  1,  3,
#         5, -1,  5,  6,  6,  1,  1,  5,  1,  1,  1, 12,  1, 11,  0,  1,  5,
#         1,  4])

# %%
plt.scatter(X[:, 0], X[:, 1], c=dbscan.labels_)

# %%
import numpy as np
index = np.where(predictions < 0)

# %%
plt.scatter(X[:, 0], X[:,1])
plt.scatter(X[index, 0], X[index,1], edgecolors='r')
plt.show()
